# %% [markdown]
# # Exploración inicial del dataset olímpico
#
# Este notebook se reserva para comprobaciones exploratorias: dimensiones, valores faltantes, cobertura biométrica y validación de grupos deportivos. La preparación reproducible final se encuentra en `scripts/03_export_infogram_tables.py`.

# %%
import pandas as pd

df = pd.read_csv('../data/raw/olympics.csv')
df.shape, df.head()

# %%
df[['Age', 'Height', 'Weight']].isna().mean().mul(100).round(1)
